# %%
# 기본 모듈 로드 (numpy, pandas)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# sklearn 모듈 로드
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# torch 임포트
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import math # Positional Encoding에 사용

# 시드 설정 (재현성 확보)
torch.manual_seed(0)
np.random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# GPU 사용 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
import os
# Out:
# /home/shinds/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Using device: cuda

# %%
os.getcwd()
# Out:
# '/home/shinds/my_document/advrobot/3_forecasting'

# %%
print("### 데이터 로딩 및 전처리 ###")
# 기초데이터 불러오기
# 파일 경로는 실제 파일 위치에 맞게 수정해주세요.
try:
    X = pd.read_csv('../BASEL_X.csv')
    Y = pd.read_csv('../BASEL_Y.csv') # Y는 예측 문제에서는 사용하지 않음
except FileNotFoundError:
    print("CSV 파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
    exit()

# 데이터 시간 순 정렬 (시계열 처리에 필수)
X['DATE'] = pd.to_datetime(X['DATE'])
X = X.sort_values(by='DATE').reset_index(drop=True)




feature_columns = [
    
    'BASEL_global_radiation', 'BASEL_precipitation','BASEL_temp_mean'
    
]
target_column = 'BASEL_temp_mean' # 예측할 컬럼 이름
input_dim = len(feature_columns) # 입력 특징 차원
output_dim = 1 # 예측할 출력 특징 차원 (temp_mean 하나)

X_pre = X[feature_columns]

# 스케일링 (시계열 데이터 전체에 대해 수행)
# MinMaxScaler는 0-1 범위로 스케일링하여 신경망 학습에 안정적
#scaler = MinMaxScaler()

#X_scaled = scaler.fit_transform(X_pre)
#X_scaled_df = pd.DataFrame(X_scaled, columns=feature_columns) # 스케일링된 데이터로 DataFrame 재생성
X_scaled_df = X_pre.copy()

print(f"스케일링 완료된 데이터 Shape: {X_scaled_df.shape}")
# Out:
# ### 데이터 로딩 및 전처리 ###
# 스케일링 완료된 데이터 Shape: (3654, 3)

# %%
print("\n### 시퀀스 데이터 생성 ###")
# 시계열 시퀀스 (window) 생성
# 이전 window_in 길이로 다음 window_out 길이 예측

window_in = 4 # 입력 시퀀스 길이 (이전 4일)
window_out = 3 # 예측 시퀀스 길이 (다음 3일)
stride = 1 # 시퀀스 생성 시 이동 간격 (데이터 양을 늘리기 위해 1로 설정)

X_ts, Y_ts = [], []
# 슬라이딩 윈도우 적용
# 시퀀스 생성 범위: [start]부터 [start + window_in + window_out - 1]까지
# 예측 대상의 마지막 시점 인덱스는 start + window_in + window_out - 1
for start in range(0, len(X_scaled_df) - window_in - window_out + 1, stride):
    end_input = start + window_in # 입력 시퀀스 끝 인덱스 (포함 안됨)
    end_output = end_input + window_out # 출력 시퀀스 끝 인덱스 (포함 안됨)

    # 입력 시퀀스: start 부터 end_input-1 까지의 모든 특징
    x_seq = X_scaled_df.iloc[start : end_input, :].values
    # 출력 시퀀스: end_input 부터 end_output-1 까지의 'temp_mean' 값
    # Y_ts는 (num_sequences, window_out) 형태가 되도록 함
    y_seq = X_scaled_df.iloc[end_input : end_output, X_scaled_df.columns.get_loc(target_column)].values

    X_ts.append(x_seq)
    Y_ts.append(y_seq)

X_ts_np = np.array(X_ts)
Y_ts_np = np.array(Y_ts) # Shape: (num_sequences, window_out)

print(f"생성된 입력 시퀀스 Shape: {X_ts_np.shape} (num_sequences, window_in, input_dim)")
print(f"생성된 출력 시퀀스 Shape: {Y_ts_np.shape} (num_sequences, window_out)")
# Out:
# ### 시퀀스 데이터 생성 ###
# 생성된 입력 시퀀스 Shape: (3648, 4, 3) (num_sequences, window_in, input_dim)
# 생성된 출력 시퀀스 Shape: (3648, 3) (num_sequences, window_out)

# %%
print("\n### Train, Validation, Test set 분할 (시간 순서 기준, 고정 Test Set) ###")

total_sequences = X_ts_np.shape[0]
test_size = 400  # 테스트셋은 마지막 400개 고정
remaining_size = total_sequences - test_size

# 나머지 데이터를 train/val로 비율 나누기
train_ratio = 0.6  # train/validation 분할 비율 (남은 데이터 기준)

train_size = int(remaining_size * train_ratio)
val_size = remaining_size - train_size

# 데이터 분할
X_train = X_ts_np[:train_size]
Y_train = Y_ts_np[:train_size]

X_val = X_ts_np[train_size : train_size + val_size]
Y_val = Y_ts_np[train_size : train_size + val_size]

X_test = X_ts_np[remaining_size:]  # 마지막 400개
Y_test = Y_ts_np[remaining_size:]

print(f"Train set Shape: {X_train.shape}, {Y_train.shape}")
print(f"Validation set Shape: {X_val.shape}, {Y_val.shape}")
print(f"Test set Shape: {X_test.shape}, {Y_test.shape}")
# Out:
# ### Train, Validation, Test set 분할 (시간 순서 기준, 고정 Test Set) ###
# Train set Shape: (1948, 4, 3), (1948, 3)
# Validation set Shape: (1300, 4, 3), (1300, 3)
# Test set Shape: (400, 4, 3), (400, 3)

# %%
print("\n### PyTorch DataLoader 준비 ###")
# TensorDataset 및 DataLoader 생성
# Y_train/Y_val/Y_test는 예측할 대상 시퀀스 (shape: ..., window_out)
D_train = TensorDataset(torch.Tensor(X_train).to(device), torch.Tensor(Y_train).to(device))
D_val = TensorDataset(torch.Tensor(X_val).to(device), torch.Tensor(Y_val).to(device))
D_test = TensorDataset(torch.Tensor(X_test).to(device), torch.Tensor(Y_test).to(device))

# 트랜스포머는 메모리를 더 사용할 수 있으므로 배치 사이즈를 조정
batch_size = 128
Train_Loader = DataLoader(D_train, batch_size=batch_size, shuffle=True, drop_last=False) # 학습 시 셔플
Val_Loader = DataLoader(D_val, batch_size=batch_size, shuffle=False, drop_last=False) # 검증 시 셔플 안 함
Test_Loader = DataLoader(D_test, batch_size=batch_size, shuffle=False, drop_last=False) # 테스트 시 셔플 안 함

print(f"Train_Loader 배치 개수: {len(Train_Loader)}")
print(f"Val_Loader 배치 개수: {len(Val_Loader)}")
print(f"Test_Loader 배치 개수: {len(Test_Loader)}")
# Out:
# ### PyTorch DataLoader 준비 ###
# Train_Loader 배치 개수: 16
# Val_Loader 배치 개수: 11
# Test_Loader 배치 개수: 4

# %%
print("\n### Transformer 모델 정의 및 학습 ###")

# Positional Encoding 모듈 (시퀀스 순서 정보 추가)
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1) # Shape: (max_len, 1, d_model)
        self.register_buffer('pe', pe) # pe is not a trainable parameter

    def forward(self, x):
        # x shape: (seq_len, batch_size, d_model)
        # self.pe shape: (max_len, 1, d_model)
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)


# Transformer Encoder-Decoder 모델
class TransformerPredictor(nn.Module):
    def __init__(self, input_dim, output_dim, d_model, nhead, num_encoder_layers, num_decoder_layers, dropout=0.1):
        super().__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model
        self.output_dim = output_dim # 예측할 출력 차원 (여기서는 1)

        # 입력 특징 차원 -> d_model 차원으로 매핑하는 레이어
        self.encoder_input_layer = nn.Linear(input_dim, d_model)
        # 디코더 입력 특징 차원 (예측 대상의 차원) -> d_model 차원으로 매핑하는 레이어
        self.decoder_input_layer = nn.Linear(output_dim, d_model)
        # 트랜스포머 디코더 출력 (d_model) -> 최종 출력 차원 (output_dim)으로 매핑하는 레이어
        self.output_layer = nn.Linear(d_model, output_dim)

        # Positional Encoding 레이어
        self.pos_encoder = PositionalEncoding(d_model, dropout)
        self.pos_decoder = PositionalEncoding(d_model, dropout) # 디코더도 Positional Encoding 필요

        # 트랜스포머 핵심 레이어
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_encoder_layers)

        decoder_layers = nn.TransformerDecoderLayer(d_model, nhead, dropout=dropout)
        self.transformer_decoder = nn.TransformerDecoder(decoder_layers, num_decoder_layers)

        # Initialization (optional, but can help)
        self.init_weights()

    def init_weights(self):
        # 가중치 초기화 (예시)
        initrange = 0.1
        self.encoder_input_layer.weight.data.uniform_(-initrange, initrange)
        self.decoder_input_layer.weight.data.uniform_(-initrange, initrange)
        self.output_layer.bias.data.zero_()
        self.output_layer.weight.data.uniform_(-initrange, initrange)


    def forward(self, src, tgt, src_mask, tgt_mask):
        # src shape: (batch_size, seq_in, input_dim) - Encoder 입력
        # tgt shape: (batch_size, seq_out, output_dim) - Decoder 입력 (학습 시 Teacher Forcing)

        # 트랜스포머 레이어는 (seq_len, batch_size, feature_dim) 형태 입력을 선호하므로 차원 변경
        src = src.permute(1, 0, 2) # -> (seq_in, batch_size, input_dim)
        tgt = tgt.permute(1, 0, 2) # -> (seq_out, batch_size, output_dim)

        # 입력/출력 선형 레이어 및 Positional Encoding 적용
        src = self.encoder_input_layer(src) # -> (seq_in, batch_size, d_model)
        src = self.pos_encoder(src)        # + Positional Encoding

        tgt = self.decoder_input_layer(tgt) # -> (seq_out, batch_size, d_model)
        tgt = self.pos_decoder(tgt)        # + Positional Encoding


        # 트랜스포머 순전파
        memory = self.transformer_encoder(src, src_mask) # memory shape: (seq_in, batch_size, d_model)
        # 디코더 입력: tgt, 메모리: memory (인코더 출력), 타겟 마스크: tgt_mask (인과적 마스크), 메모리 마스크: None
        output = self.transformer_decoder(tgt, memory, tgt_mask, None) # output shape: (seq_out, batch_size, d_model)

        # 최종 출력 레이어 적용
        output = self.output_layer(output) # -> (seq_out, batch_size, output_dim)

        # 원래 배치 형태로 차원 변경 (batch_size, seq_len, feature_dim)
        output = output.permute(1, 0, 2) # -> (batch_size, seq_out, output_dim)

        return output # 최종 예측 시퀀스

# Helper function to generate causal mask (look-ahead mask)
# 디코더가 미래 시점의 정보를 보지 못하도록 마스크 생성
def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    # 마스크 형태: (sz, sz)
    return mask.to(device)


# Helper function to shift the target sequence for decoder input (Teacher Forcing용)
# 타겟 시퀀스를 오른쪽으로 한 스텝 쉬프트하고 시작 토큰(여기서는 0 벡터)을 앞에 붙임
def shift_sequence(sequence, start_token_value=0.0):
    # sequence shape: (batch_size, seq_len, feature_dim)
    batch_size, seq_len, feature_dim = sequence.size()
    # 시작 토큰: (batch_size, 1, feature_dim)
    start_token = torch.full((batch_size, 1, feature_dim), start_token_value, device=sequence.device)
    # 실제 시퀀스는 마지막 요소 제외
    shifted_sequence = sequence[:, :-1, :]
    # 시작 토큰과 실제 시퀀스 연결
    shifted_sequence = torch.cat([start_token, shifted_sequence], dim=1)
    # 최종 shape: (batch_size, seq_len, feature_dim)
    return shifted_sequence
# Out:
# ### Transformer 모델 정의 및 학습 ###

# %%
# 모델 파라미터 (하이퍼파라미터)
d_model = 64
nhead = 8
num_encoder_layers = 2
num_decoder_layers = 2
dropout = 0.1

transformer_model = TransformerPredictor(
    input_dim,
    output_dim,
    d_model,
    nhead,
    num_encoder_layers,
    num_decoder_layers,
    dropout
).to(device)

# 손실 함수 및 옵티마이저
criterion = nn.MSELoss()
optimizer = optim.Adam(transformer_model.parameters(), lr=1e-4)

# 학습 파라미터
num_epochs = 300
best_val_loss = float('inf')
patience = 30
epochs_no_improve = 0
noise_std = 0.01

# Adaptive Scheduled Sampling 설정
initial_teacher_forcing_ratio = 1.0
final_teacher_forcing_ratio = 0.1
decay_epochs = 100  # 몇 epoch 동안 teacher forcing ratio를 선형 감소할지
teacher_forcing_ratio = initial_teacher_forcing_ratio
print(f"Adaptive Scheduled Sampling 학습 시작 ({num_epochs} 에폭)...")

for epoch in range(num_epochs):
    transformer_model.train()
    total_train_loss = 0

    for batch_x, batch_y in Train_Loader:
        batch_y = batch_y.unsqueeze(-1)

        # Noise Injection
        batch_x_noisy = batch_x + torch.randn_like(batch_x) * noise_std
        optimizer.zero_grad()

        batch_size = batch_x_noisy.size(0)
        decoder_input_sequence = torch.full((batch_size, 1, output_dim), 0.0, device=device)

        src_mask = None
        memory = transformer_model.transformer_encoder(
            transformer_model.pos_encoder(transformer_model.encoder_input_layer(batch_x_noisy.permute(1, 0, 2))),
            src_mask
        )

        outputs = []
        for t in range(window_out):
            tgt = transformer_model.pos_decoder(
                transformer_model.decoder_input_layer(decoder_input_sequence.permute(1, 0, 2))
            )
            tgt_mask = generate_square_subsequent_mask(decoder_input_sequence.size(1))

            output = transformer_model.transformer_decoder(tgt, memory, tgt_mask)
            prediction = transformer_model.output_layer(output[-1, :, :])
            outputs.append(prediction.unsqueeze(1))

            # Adaptive Scheduled Sampling 적용
            use_teacher_forcing = np.random.rand() < teacher_forcing_ratio
            if use_teacher_forcing:
                next_input = batch_y[:, t, :].unsqueeze(1)
            else:
                next_input = prediction.unsqueeze(1)

            decoder_input_sequence = torch.cat([decoder_input_sequence, next_input], dim=1)

        outputs = torch.cat(outputs, dim=1)

        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item() * batch_x.size(0)

    avg_train_loss = total_train_loss / len(Train_Loader.dataset)

    # Validation
    transformer_model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for batch_x_val, batch_y_val in Val_Loader:
            batch_y_val = batch_y_val.unsqueeze(-1)

            decoder_input_sequence_val = shift_sequence(batch_y_val, start_token_value=0.0)
            prediction_seq_val = transformer_model(batch_x_val, decoder_input_sequence_val, None, generate_square_subsequent_mask(window_out))
            val_loss = criterion(prediction_seq_val, batch_y_val)

            total_val_loss += val_loss.item() * batch_x_val.size(0)

    avg_val_loss = total_val_loss / len(Val_Loader.dataset)

    # --- Teacher Forcing Ratio 선형 감소 ---
    teacher_forcing_ratio = max(
        final_teacher_forcing_ratio,
        initial_teacher_forcing_ratio - (epoch / decay_epochs) * (initial_teacher_forcing_ratio - final_teacher_forcing_ratio)
    )

    # 출력
    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss = {avg_train_loss:.6f}, Val Loss = {avg_val_loss:.6f}, Teacher Forcing Ratio = {teacher_forcing_ratio:.3f}")

    # Early Stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"조기 종료! 검증 손실이 {patience} 에폭 동안 개선되지 않았습니다.")
            break

print("Transformer 모델 Adaptive Scheduled Sampling 학습 완료.")
# Out:
# /home/shinds/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Adaptive Scheduled Sampling 학습 시작 (300 에폭)...
# Epoch 1/300: Train Loss = 128.396921, Val Loss = 116.241623, Teacher Forcing Ratio = 1.000
# Epoch 2/300: Train Loss = 103.845590, Val Loss = 111.519313, Teacher Forcing Ratio = 0.991
# Epoch 3/300: Train Loss = 101.378979, Val Loss = 109.737729, Teacher Forcing Ratio = 0.982
# Epoch 4/300: Train Loss = 99.567906, Val Loss = 107.643926, Teacher Forcing Ratio = 0.973
# Epoch 5/300: Train Loss = 97.357746, Val Loss = 105.213271, Teacher Forcing Ratio = 0.964
# Epoch 6/300: Train Loss = 95.282051, Val Loss = 103.322117, Teacher Forcing Ratio = 0.955
# Epoch 7/300: Train Loss = 93.560594, Val Loss = 101.679446, Teacher Forcing Ratio = 0.946
# Epoch 8/300: Train Loss = 91.989888, Val Loss = 99.801626, Teacher Forcing Ratio = 0.937
# Epoch 9/300: Train Loss = 90.218803, Val Loss = 98.073123, Teacher Forcing Ratio = 0.928
# Epoch 10/300: Train Loss = 88.576914, Val Loss = 96.268061, Teacher Forcing Ratio = 0.919
# Epoch 11/300: Train Loss = 87.081922, Val Loss = 94.468310, Teacher Forcing Ratio = 0.910
# Epoch 12/300: Train Loss = 85.443286, Val Loss = 92.730073, Teacher Forcing Ratio = 0.901
# Epoch 13/300: Train Loss = 83.876146, Val Loss = 90.997738, Teacher Forcing Ratio = 0.892
# Epoch 14/300: Train Loss = 82.287556, Val Loss = 89.309816, Teacher Forcing Ratio = 0.883
# Epoch 15/300: Train Loss = 81.032691, Val Loss = 87.694631, Teacher Forcing Ratio = 0.874
# Epoch 16/300: Train Loss = 79.405859, Val Loss = 86.191320, Teacher Forcing Ratio = 0.865
# Epoch 17/300: Train Loss = 77.977062, Val Loss = 84.572678, Teacher Forcing Ratio = 0.856
# Epoch 18/300: Train Loss = 76.464090, Val Loss = 82.892213, Teacher Forcing Ratio = 0.847
# Epoch 19/300: Train Loss = 74.964049, Val Loss = 81.321220, Teacher Forcing Ratio = 0.838
# Epoch 20/300: Train Loss = 73.633291, Val Loss = 79.743969, Teacher Forcing Ratio = 0.829
# Epoch 21/300: Train Loss = 72.248380, Val Loss = 78.283514, Teacher Forcing Ratio = 0.820
# Epoch 22/300: Train Loss = 70.905490, Val Loss = 76.719007, Teacher Forcing Ratio = 0.811
# Epoch 23/300: Train Loss = 69.540046, Val Loss = 75.232677, Teacher Forcing Ratio = 0.802
# Epoch 24/300: Train Loss = 68.298782, Val Loss = 73.787601, Teacher Forcing Ratio = 0.793
# Epoch 25/300: Train Loss = 66.971474, Val Loss = 72.387548, Teacher Forcing Ratio = 0.784
# Epoch 26/300: Train Loss = 65.716876, Val Loss = 70.980598, Teacher Forcing Ratio = 0.775
# Epoch 27/300: Train Loss = 64.359044, Val Loss = 69.635869, Teacher Forcing Ratio = 0.766
# Epoch 28/300: Train Loss = 63.180727, Val Loss = 68.088862, Teacher Forcing Ratio = 0.757
# Epoch 29/300: Train Loss = 61.854881, Val Loss = 66.756610, Teacher Forcing Ratio = 0.748
# Epoch 30/300: Train Loss = 60.828644, Val Loss = 65.437964, Teacher Forcing Ratio = 0.739
# Epoch 31/300: Train Loss = 59.614517, Val Loss = 64.061630, Teacher Forcing Ratio = 0.730
# Epoch 32/300: Train Loss = 58.352338, Val Loss = 62.750137, Teacher Forcing Ratio = 0.721
# Epoch 33/300: Train Loss = 57.124469, Val Loss = 61.643699, Teacher Forcing Ratio = 0.712
# Epoch 34/300: Train Loss = 56.028528, Val Loss = 60.159352, Teacher Forcing Ratio = 0.703
# Epoch 35/300: Train Loss = 55.055625, Val Loss = 58.912320, Teacher Forcing Ratio = 0.694
# Epoch 36/300: Train Loss = 54.009507, Val Loss = 57.753968, Teacher Forcing Ratio = 0.685
# Epoch 37/300: Train Loss = 52.718788, Val Loss = 56.652803, Teacher Forcing Ratio = 0.676
# Epoch 38/300: Train Loss = 51.773664, Val Loss = 55.328055, Teacher Forcing Ratio = 0.667
# Epoch 39/300: Train Loss = 50.608205, Val Loss = 54.114070, Teacher Forcing Ratio = 0.658
# Epoch 40/300: Train Loss = 49.633540, Val Loss = 52.979421, Teacher Forcing Ratio = 0.649
# Epoch 41/300: Train Loss = 48.639307, Val Loss = 51.776332, Teacher Forcing Ratio = 0.640
# Epoch 42/300: Train Loss = 47.605076, Val Loss = 50.721972, Teacher Forcing Ratio = 0.631
# Epoch 43/300: Train Loss = 46.601999, Val Loss = 49.544422, Teacher Forcing Ratio = 0.622
# Epoch 44/300: Train Loss = 45.607197, Val Loss = 48.512016, Teacher Forcing Ratio = 0.613
# Epoch 45/300: Train Loss = 44.684598, Val Loss = 47.393604, Teacher Forcing Ratio = 0.604
# Epoch 46/300: Train Loss = 43.684849, Val Loss = 46.269924, Teacher Forcing Ratio = 0.595
# Epoch 47/300: Train Loss = 42.808575, Val Loss = 45.212863, Teacher Forcing Ratio = 0.586
# Epoch 48/300: Train Loss = 41.856687, Val Loss = 44.283193, Teacher Forcing Ratio = 0.577
# Epoch 49/300: Train Loss = 41.236192, Val Loss = 43.187054, Teacher Forcing Ratio = 0.568
# Epoch 50/300: Train Loss = 40.143190, Val Loss = 42.271837, Teacher Forcing Ratio = 0.559
# Epoch 51/300: Train Loss = 39.361765, Val Loss = 41.265782, Teacher Forcing Ratio = 0.550
# Epoch 52/300: Train Loss = 38.492611, Val Loss = 40.413144, Teacher Forcing Ratio = 0.541
# Epoch 53/300: Train Loss = 38.028747, Val Loss = 39.574345, Teacher Forcing Ratio = 0.532
# Epoch 54/300: Train Loss = 37.156995, Val Loss = 38.737032, Teacher Forcing Ratio = 0.523
# Epoch 55/300: Train Loss = 36.174671, Val Loss = 37.598170, Teacher Forcing Ratio = 0.514
# Epoch 56/300: Train Loss = 35.554429, Val Loss = 36.710190, Teacher Forcing Ratio = 0.505
# Epoch 57/300: Train Loss = 34.758730, Val Loss = 35.827547, Teacher Forcing Ratio = 0.496
# Epoch 58/300: Train Loss = 33.930809, Val Loss = 35.020870, Teacher Forcing Ratio = 0.487
# Epoch 59/300: Train Loss = 33.815202, Val Loss = 34.196975, Teacher Forcing Ratio = 0.478
# Epoch 60/300: Train Loss = 32.671455, Val Loss = 33.446697, Teacher Forcing Ratio = 0.469
# Epoch 61/300: Train Loss = 32.018764, Val Loss = 32.589503, Teacher Forcing Ratio = 0.460
# Epoch 62/300: Train Loss = 31.373975, Val Loss = 31.897838, Teacher Forcing Ratio = 0.451
# Epoch 63/300: Train Loss = 30.600567, Val Loss = 31.106275, Teacher Forcing Ratio = 0.442
# Epoch 64/300: Train Loss = 30.517659, Val Loss = 30.364312, Teacher Forcing Ratio = 0.433
# Epoch 65/300: Train Loss = 29.615607, Val Loss = 29.708136, Teacher Forcing Ratio = 0.424
# Epoch 66/300: Train Loss = 28.835293, Val Loss = 28.925519, Teacher Forcing Ratio = 0.415
# Epoch 67/300: Train Loss = 28.586613, Val Loss = 28.304744, Teacher Forcing Ratio = 0.406
# Epoch 68/300: Train Loss = 27.600693, Val Loss = 27.595532, Teacher Forcing Ratio = 0.397
# Epoch 69/300: Train Loss = 27.259308, Val Loss = 26.957085, Teacher Forcing Ratio = 0.388
# Epoch 70/300: Train Loss = 26.726780, Val Loss = 26.382856, Teacher Forcing Ratio = 0.379
# Epoch 71/300: Train Loss = 25.757655, Val Loss = 25.594204, Teacher Forcing Ratio = 0.370
# Epoch 72/300: Train Loss = 26.262282, Val Loss = 25.193354, Teacher Forcing Ratio = 0.361
# Epoch 73/300: Train Loss = 25.133419, Val Loss = 24.585161, Teacher Forcing Ratio = 0.352
# Epoch 74/300: Train Loss = 24.824695, Val Loss = 23.886753, Teacher Forcing Ratio = 0.343
# Epoch 75/300: Train Loss = 24.041240, Val Loss = 23.305730, Teacher Forcing Ratio = 0.334
# Epoch 76/300: Train Loss = 23.929588, Val Loss = 22.754921, Teacher Forcing Ratio = 0.325
# Epoch 77/300: Train Loss = 23.378051, Val Loss = 22.259819, Teacher Forcing Ratio = 0.316
# Epoch 78/300: Train Loss = 22.712584, Val Loss = 21.672982, Teacher Forcing Ratio = 0.307
# Epoch 79/300: Train Loss = 22.611811, Val Loss = 21.192663, Teacher Forcing Ratio = 0.298
# Epoch 80/300: Train Loss = 22.590847, Val Loss = 21.072121, Teacher Forcing Ratio = 0.289
# Epoch 81/300: Train Loss = 22.092961, Val Loss = 20.395540, Teacher Forcing Ratio = 0.280
# Epoch 82/300: Train Loss = 21.201906, Val Loss = 19.988034, Teacher Forcing Ratio = 0.271
# Epoch 83/300: Train Loss = 21.002908, Val Loss = 19.394897, Teacher Forcing Ratio = 0.262
# Epoch 84/300: Train Loss = 20.612246, Val Loss = 19.052969, Teacher Forcing Ratio = 0.253
# Epoch 85/300: Train Loss = 20.446011, Val Loss = 18.671886, Teacher Forcing Ratio = 0.244
# Epoch 86/300: Train Loss = 20.289743, Val Loss = 18.290195, Teacher Forcing Ratio = 0.235
# Epoch 87/300: Train Loss = 20.027614, Val Loss = 17.932233, Teacher Forcing Ratio = 0.226
# Epoch 88/300: Train Loss = 19.362459, Val Loss = 17.540146, Teacher Forcing Ratio = 0.217
# Epoch 89/300: Train Loss = 19.080714, Val Loss = 17.063096, Teacher Forcing Ratio = 0.208
# Epoch 90/300: Train Loss = 18.322971, Val Loss = 16.604745, Teacher Forcing Ratio = 0.199
# Epoch 91/300: Train Loss = 18.264538, Val Loss = 16.241970, Teacher Forcing Ratio = 0.190
# Epoch 92/300: Train Loss = 18.122343, Val Loss = 16.109478, Teacher Forcing Ratio = 0.181
# Epoch 93/300: Train Loss = 17.819885, Val Loss = 15.612868, Teacher Forcing Ratio = 0.172
# Epoch 94/300: Train Loss = 18.093201, Val Loss = 15.288331, Teacher Forcing Ratio = 0.163
# Epoch 95/300: Train Loss = 17.165518, Val Loss = 14.995605, Teacher Forcing Ratio = 0.154
# Epoch 96/300: Train Loss = 17.273565, Val Loss = 14.936064, Teacher Forcing Ratio = 0.145
# Epoch 97/300: Train Loss = 17.124165, Val Loss = 14.587730, Teacher Forcing Ratio = 0.136
# Epoch 98/300: Train Loss = 16.669035, Val Loss = 14.335151, Teacher Forcing Ratio = 0.127
# Epoch 99/300: Train Loss = 16.558123, Val Loss = 14.020286, Teacher Forcing Ratio = 0.118
# Epoch 100/300: Train Loss = 16.421573, Val Loss = 13.793259, Teacher Forcing Ratio = 0.109
# Epoch 101/300: Train Loss = 16.317905, Val Loss = 13.677015, Teacher Forcing Ratio = 0.100
# Epoch 102/300: Train Loss = 15.964850, Val Loss = 13.606631, Teacher Forcing Ratio = 0.100
# Epoch 103/300: Train Loss = 15.803279, Val Loss = 13.290940, Teacher Forcing Ratio = 0.100
# Epoch 104/300: Train Loss = 15.450996, Val Loss = 13.033818, Teacher Forcing Ratio = 0.100
# Epoch 105/300: Train Loss = 15.317465, Val Loss = 12.818269, Teacher Forcing Ratio = 0.100
# Epoch 106/300: Train Loss = 15.243859, Val Loss = 12.626589, Teacher Forcing Ratio = 0.100
# Epoch 107/300: Train Loss = 14.921760, Val Loss = 12.437695, Teacher Forcing Ratio = 0.100
# Epoch 108/300: Train Loss = 14.572965, Val Loss = 12.232725, Teacher Forcing Ratio = 0.100
# Epoch 109/300: Train Loss = 14.362537, Val Loss = 12.076454, Teacher Forcing Ratio = 0.100
# Epoch 110/300: Train Loss = 14.152218, Val Loss = 11.675141, Teacher Forcing Ratio = 0.100
# Epoch 111/300: Train Loss = 13.984401, Val Loss = 11.521766, Teacher Forcing Ratio = 0.100
# Epoch 112/300: Train Loss = 13.971720, Val Loss = 11.346960, Teacher Forcing Ratio = 0.100
# Epoch 113/300: Train Loss = 13.613360, Val Loss = 11.146035, Teacher Forcing Ratio = 0.100
# Epoch 114/300: Train Loss = 13.636075, Val Loss = 11.025555, Teacher Forcing Ratio = 0.100
# Epoch 115/300: Train Loss = 13.446159, Val Loss = 10.889162, Teacher Forcing Ratio = 0.100
# Epoch 116/300: Train Loss = 13.616763, Val Loss = 10.961887, Teacher Forcing Ratio = 0.100
# Epoch 117/300: Train Loss = 13.283393, Val Loss = 11.167232, Teacher Forcing Ratio = 0.100
# Epoch 118/300: Train Loss = 13.294262, Val Loss = 10.583990, Teacher Forcing Ratio = 0.100
# Epoch 119/300: Train Loss = 12.827733, Val Loss = 10.407642, Teacher Forcing Ratio = 0.100
# Epoch 120/300: Train Loss = 12.429910, Val Loss = 10.132970, Teacher Forcing Ratio = 0.100
# Epoch 121/300: Train Loss = 12.478210, Val Loss = 9.987041, Teacher Forcing Ratio = 0.100
# Epoch 122/300: Train Loss = 12.375577, Val Loss = 9.911913, Teacher Forcing Ratio = 0.100
# Epoch 123/300: Train Loss = 12.557399, Val Loss = 9.769963, Teacher Forcing Ratio = 0.100
# Epoch 124/300: Train Loss = 12.228725, Val Loss = 9.695770, Teacher Forcing Ratio = 0.100
# Epoch 125/300: Train Loss = 12.361882, Val Loss = 9.668396, Teacher Forcing Ratio = 0.100
# Epoch 126/300: Train Loss = 11.960240, Val Loss = 9.520809, Teacher Forcing Ratio = 0.100
# Epoch 127/300: Train Loss = 11.528423, Val Loss = 9.380911, Teacher Forcing Ratio = 0.100
# Epoch 128/300: Train Loss = 12.075460, Val Loss = 9.337030, Teacher Forcing Ratio = 0.100
# Epoch 129/300: Train Loss = 11.740332, Val Loss = 9.231660, Teacher Forcing Ratio = 0.100
# Epoch 130/300: Train Loss = 11.612208, Val Loss = 9.268384, Teacher Forcing Ratio = 0.100
# Epoch 131/300: Train Loss = 11.424622, Val Loss = 8.953392, Teacher Forcing Ratio = 0.100
# Epoch 132/300: Train Loss = 11.507158, Val Loss = 8.794323, Teacher Forcing Ratio = 0.100
# Epoch 133/300: Train Loss = 11.539151, Val Loss = 8.709072, Teacher Forcing Ratio = 0.100
# Epoch 134/300: Train Loss = 11.282568, Val Loss = 8.615745, Teacher Forcing Ratio = 0.100
# Epoch 135/300: Train Loss = 10.738454, Val Loss = 8.456567, Teacher Forcing Ratio = 0.100
# Epoch 136/300: Train Loss = 10.955084, Val Loss = 8.299562, Teacher Forcing Ratio = 0.100
# Epoch 137/300: Train Loss = 10.994255, Val Loss = 8.284666, Teacher Forcing Ratio = 0.100
# Epoch 138/300: Train Loss = 10.888387, Val Loss = 8.103107, Teacher Forcing Ratio = 0.100
# Epoch 139/300: Train Loss = 11.179199, Val Loss = 8.202881, Teacher Forcing Ratio = 0.100
# Epoch 140/300: Train Loss = 10.867155, Val Loss = 8.273736, Teacher Forcing Ratio = 0.100
# Epoch 141/300: Train Loss = 10.646338, Val Loss = 8.164400, Teacher Forcing Ratio = 0.100
# Epoch 142/300: Train Loss = 11.020812, Val Loss = 8.120049, Teacher Forcing Ratio = 0.100
# Epoch 143/300: Train Loss = 10.805016, Val Loss = 8.220828, Teacher Forcing Ratio = 0.100
# Epoch 144/300: Train Loss = 10.491588, Val Loss = 7.991010, Teacher Forcing Ratio = 0.100
# Epoch 145/300: Train Loss = 10.553838, Val Loss = 8.034466, Teacher Forcing Ratio = 0.100
# Epoch 146/300: Train Loss = 10.661784, Val Loss = 8.063040, Teacher Forcing Ratio = 0.100
# Epoch 147/300: Train Loss = 10.664016, Val Loss = 8.001304, Teacher Forcing Ratio = 0.100
# Epoch 148/300: Train Loss = 10.485704, Val Loss = 7.910951, Teacher Forcing Ratio = 0.100
# Epoch 149/300: Train Loss = 10.225330, Val Loss = 7.952077, Teacher Forcing Ratio = 0.100
# Epoch 150/300: Train Loss = 10.242924, Val Loss = 8.083231, Teacher Forcing Ratio = 0.100
# Epoch 151/300: Train Loss = 10.281742, Val Loss = 7.987968, Teacher Forcing Ratio = 0.100
# Epoch 152/300: Train Loss = 10.357132, Val Loss = 7.962741, Teacher Forcing Ratio = 0.100
# Epoch 153/300: Train Loss = 9.931467, Val Loss = 7.696566, Teacher Forcing Ratio = 0.100
# Epoch 154/300: Train Loss = 10.121345, Val Loss = 7.689641, Teacher Forcing Ratio = 0.100
# Epoch 155/300: Train Loss = 9.915927, Val Loss = 7.660895, Teacher Forcing Ratio = 0.100
# Epoch 156/300: Train Loss = 10.030816, Val Loss = 7.831005, Teacher Forcing Ratio = 0.100
# Epoch 157/300: Train Loss = 10.099118, Val Loss = 7.601215, Teacher Forcing Ratio = 0.100
# Epoch 158/300: Train Loss = 10.028005, Val Loss = 7.647692, Teacher Forcing Ratio = 0.100
# Epoch 159/300: Train Loss = 9.775570, Val Loss = 7.505917, Teacher Forcing Ratio = 0.100
# Epoch 160/300: Train Loss = 9.458207, Val Loss = 7.439454, Teacher Forcing Ratio = 0.100
# Epoch 161/300: Train Loss = 9.841605, Val Loss = 7.292656, Teacher Forcing Ratio = 0.100
# Epoch 162/300: Train Loss = 9.765851, Val Loss = 7.248860, Teacher Forcing Ratio = 0.100
# Epoch 163/300: Train Loss = 9.480072, Val Loss = 7.118241, Teacher Forcing Ratio = 0.100
# Epoch 164/300: Train Loss = 9.490503, Val Loss = 7.062509, Teacher Forcing Ratio = 0.100
# Epoch 165/300: Train Loss = 9.610942, Val Loss = 7.111979, Teacher Forcing Ratio = 0.100
# Epoch 166/300: Train Loss = 9.694805, Val Loss = 7.161319, Teacher Forcing Ratio = 0.100
# Epoch 167/300: Train Loss = 9.440199, Val Loss = 7.022956, Teacher Forcing Ratio = 0.100
# Epoch 168/300: Train Loss = 9.478969, Val Loss = 7.076744, Teacher Forcing Ratio = 0.100
# Epoch 169/300: Train Loss = 9.754949, Val Loss = 7.010533, Teacher Forcing Ratio = 0.100
# Epoch 170/300: Train Loss = 9.568347, Val Loss = 7.014537, Teacher Forcing Ratio = 0.100
# Epoch 171/300: Train Loss = 9.434742, Val Loss = 7.067883, Teacher Forcing Ratio = 0.100
# Epoch 172/300: Train Loss = 9.626081, Val Loss = 7.047336, Teacher Forcing Ratio = 0.100
# Epoch 173/300: Train Loss = 9.535784, Val Loss = 7.064515, Teacher Forcing Ratio = 0.100
# Epoch 174/300: Train Loss = 9.126597, Val Loss = 7.122129, Teacher Forcing Ratio = 0.100
# Epoch 175/300: Train Loss = 9.352860, Val Loss = 7.115415, Teacher Forcing Ratio = 0.100
# Epoch 176/300: Train Loss = 9.326563, Val Loss = 7.002377, Teacher Forcing Ratio = 0.100
# Epoch 177/300: Train Loss = 9.414229, Val Loss = 7.075398, Teacher Forcing Ratio = 0.100
# Epoch 178/300: Train Loss = 9.247051, Val Loss = 6.983111, Teacher Forcing Ratio = 0.100
# Epoch 179/300: Train Loss = 9.122176, Val Loss = 6.893763, Teacher Forcing Ratio = 0.100
# Epoch 180/300: Train Loss = 9.152352, Val Loss = 6.985806, Teacher Forcing Ratio = 0.100
# Epoch 181/300: Train Loss = 9.121904, Val Loss = 6.897362, Teacher Forcing Ratio = 0.100
# Epoch 182/300: Train Loss = 9.308972, Val Loss = 6.833448, Teacher Forcing Ratio = 0.100
# Epoch 183/300: Train Loss = 9.325672, Val Loss = 6.966784, Teacher Forcing Ratio = 0.100
# Epoch 184/300: Train Loss = 9.296218, Val Loss = 7.037400, Teacher Forcing Ratio = 0.100
# Epoch 185/300: Train Loss = 8.883969, Val Loss = 6.883968, Teacher Forcing Ratio = 0.100
# Epoch 186/300: Train Loss = 9.106364, Val Loss = 6.789375, Teacher Forcing Ratio = 0.100
# Epoch 187/300: Train Loss = 9.212320, Val Loss = 6.748700, Teacher Forcing Ratio = 0.100
# Epoch 188/300: Train Loss = 8.803596, Val Loss = 6.607216, Teacher Forcing Ratio = 0.100
# Epoch 189/300: Train Loss = 9.024342, Val Loss = 6.704495, Teacher Forcing Ratio = 0.100
# Epoch 190/300: Train Loss = 9.038052, Val Loss = 6.705862, Teacher Forcing Ratio = 0.100
# Epoch 191/300: Train Loss = 9.401802, Val Loss = 6.780774, Teacher Forcing Ratio = 0.100
# Epoch 192/300: Train Loss = 9.124128, Val Loss = 6.728297, Teacher Forcing Ratio = 0.100
# Epoch 193/300: Train Loss = 8.446125, Val Loss = 6.630140, Teacher Forcing Ratio = 0.100
# Epoch 194/300: Train Loss = 8.972217, Val Loss = 6.631475, Teacher Forcing Ratio = 0.100
# Epoch 195/300: Train Loss = 8.859478, Val Loss = 6.546055, Teacher Forcing Ratio = 0.100
# Epoch 196/300: Train Loss = 9.073981, Val Loss = 6.752149, Teacher Forcing Ratio = 0.100
# Epoch 197/300: Train Loss = 8.710498, Val Loss = 6.621014, Teacher Forcing Ratio = 0.100
# Epoch 198/300: Train Loss = 8.997883, Val Loss = 6.695476, Teacher Forcing Ratio = 0.100
# Epoch 199/300: Train Loss = 8.934614, Val Loss = 6.570857, Teacher Forcing Ratio = 0.100
# Epoch 200/300: Train Loss = 8.729265, Val Loss = 6.545131, Teacher Forcing Ratio = 0.100
# Epoch 201/300: Train Loss = 8.859611, Val Loss = 6.536713, Teacher Forcing Ratio = 0.100
# Epoch 202/300: Train Loss = 8.709257, Val Loss = 6.487201, Teacher Forcing Ratio = 0.100
# Epoch 203/300: Train Loss = 8.874368, Val Loss = 6.602263, Teacher Forcing Ratio = 0.100
# Epoch 204/300: Train Loss = 8.813022, Val Loss = 6.867446, Teacher Forcing Ratio = 0.100
# Epoch 205/300: Train Loss = 8.822098, Val Loss = 6.454011, Teacher Forcing Ratio = 0.100
# Epoch 206/300: Train Loss = 8.561740, Val Loss = 6.449329, Teacher Forcing Ratio = 0.100
# Epoch 207/300: Train Loss = 8.560077, Val Loss = 6.347197, Teacher Forcing Ratio = 0.100
# Epoch 208/300: Train Loss = 8.773610, Val Loss = 6.415894, Teacher Forcing Ratio = 0.100
# Epoch 209/300: Train Loss = 8.741023, Val Loss = 6.335959, Teacher Forcing Ratio = 0.100
# Epoch 210/300: Train Loss = 8.670972, Val Loss = 6.561749, Teacher Forcing Ratio = 0.100
# Epoch 211/300: Train Loss = 8.778895, Val Loss = 6.591047, Teacher Forcing Ratio = 0.100
# Epoch 212/300: Train Loss = 8.817822, Val Loss = 6.606842, Teacher Forcing Ratio = 0.100
# Epoch 213/300: Train Loss = 8.450153, Val Loss = 6.472098, Teacher Forcing Ratio = 0.100
# Epoch 214/300: Train Loss = 8.812842, Val Loss = 6.463103, Teacher Forcing Ratio = 0.100
# Epoch 215/300: Train Loss = 8.780710, Val Loss = 6.477634, Teacher Forcing Ratio = 0.100
# Epoch 216/300: Train Loss = 8.491466, Val Loss = 6.417643, Teacher Forcing Ratio = 0.100
# Epoch 217/300: Train Loss = 8.793138, Val Loss = 6.359733, Teacher Forcing Ratio = 0.100
# Epoch 218/300: Train Loss = 8.567092, Val Loss = 6.339639, Teacher Forcing Ratio = 0.100
# Epoch 219/300: Train Loss = 8.629632, Val Loss = 6.266245, Teacher Forcing Ratio = 0.100
# Epoch 220/300: Train Loss = 8.616823, Val Loss = 6.396187, Teacher Forcing Ratio = 0.100
# Epoch 221/300: Train Loss = 8.593327, Val Loss = 6.457560, Teacher Forcing Ratio = 0.100
# Epoch 222/300: Train Loss = 8.505284, Val Loss = 6.337881, Teacher Forcing Ratio = 0.100
# Epoch 223/300: Train Loss = 8.353461, Val Loss = 6.747903, Teacher Forcing Ratio = 0.100
# Epoch 224/300: Train Loss = 8.594367, Val Loss = 6.610000, Teacher Forcing Ratio = 0.100
# Epoch 225/300: Train Loss = 8.528893, Val Loss = 6.293611, Teacher Forcing Ratio = 0.100
# Epoch 226/300: Train Loss = 8.688885, Val Loss = 6.354146, Teacher Forcing Ratio = 0.100
# Epoch 227/300: Train Loss = 8.123418, Val Loss = 6.351980, Teacher Forcing Ratio = 0.100
# Epoch 228/300: Train Loss = 8.266186, Val Loss = 6.265228, Teacher Forcing Ratio = 0.100
# Epoch 229/300: Train Loss = 8.491782, Val Loss = 6.255973, Teacher Forcing Ratio = 0.100
# Epoch 230/300: Train Loss = 8.458709, Val Loss = 6.274527, Teacher Forcing Ratio = 0.100
# Epoch 231/300: Train Loss = 8.558681, Val Loss = 6.158937, Teacher Forcing Ratio = 0.100
# Epoch 232/300: Train Loss = 8.332647, Val Loss = 6.228060, Teacher Forcing Ratio = 0.100
# Epoch 233/300: Train Loss = 8.337127, Val Loss = 6.152087, Teacher Forcing Ratio = 0.100
# Epoch 234/300: Train Loss = 8.241358, Val Loss = 6.222958, Teacher Forcing Ratio = 0.100
# Epoch 235/300: Train Loss = 8.294237, Val Loss = 6.262083, Teacher Forcing Ratio = 0.100
# Epoch 236/300: Train Loss = 8.222021, Val Loss = 5.979422, Teacher Forcing Ratio = 0.100
# Epoch 237/300: Train Loss = 8.289563, Val Loss = 5.937351, Teacher Forcing Ratio = 0.100
# Epoch 238/300: Train Loss = 8.477638, Val Loss = 6.195550, Teacher Forcing Ratio = 0.100
# Epoch 239/300: Train Loss = 8.375116, Val Loss = 6.166004, Teacher Forcing Ratio = 0.100
# Epoch 240/300: Train Loss = 8.759875, Val Loss = 6.263394, Teacher Forcing Ratio = 0.100
# Epoch 241/300: Train Loss = 8.577158, Val Loss = 6.603994, Teacher Forcing Ratio = 0.100
# Epoch 242/300: Train Loss = 8.551766, Val Loss = 6.270488, Teacher Forcing Ratio = 0.100
# Epoch 243/300: Train Loss = 8.285518, Val Loss = 6.361025, Teacher Forcing Ratio = 0.100
# Epoch 244/300: Train Loss = 8.342693, Val Loss = 6.137366, Teacher Forcing Ratio = 0.100
# Epoch 245/300: Train Loss = 8.700886, Val Loss = 6.305737, Teacher Forcing Ratio = 0.100
# Epoch 246/300: Train Loss = 8.460866, Val Loss = 6.199256, Teacher Forcing Ratio = 0.100
# Epoch 247/300: Train Loss = 8.449350, Val Loss = 6.179493, Teacher Forcing Ratio = 0.100
# Epoch 248/300: Train Loss = 8.355925, Val Loss = 6.454743, Teacher Forcing Ratio = 0.100
# Epoch 249/300: Train Loss = 8.222737, Val Loss = 6.302286, Teacher Forcing Ratio = 0.100
# Epoch 250/300: Train Loss = 8.012714, Val Loss = 6.388900, Teacher Forcing Ratio = 0.100
# Epoch 251/300: Train Loss = 8.025013, Val Loss = 6.275579, Teacher Forcing Ratio = 0.100
# Epoch 252/300: Train Loss = 8.237901, Val Loss = 6.048450, Teacher Forcing Ratio = 0.100
# Epoch 253/300: Train Loss = 8.084670, Val Loss = 6.111111, Teacher Forcing Ratio = 0.100
# Epoch 254/300: Train Loss = 8.440886, Val Loss = 6.094021, Teacher Forcing Ratio = 0.100
# Epoch 255/300: Train Loss = 8.187188, Val Loss = 6.166681, Teacher Forcing Ratio = 0.100
# Epoch 256/300: Train Loss = 8.046822, Val Loss = 6.200379, Teacher Forcing Ratio = 0.100
# Epoch 257/300: Train Loss = 8.541496, Val Loss = 6.167547, Teacher Forcing Ratio = 0.100
# Epoch 258/300: Train Loss = 8.242642, Val Loss = 6.122412, Teacher Forcing Ratio = 0.100
# Epoch 259/300: Train Loss = 8.204846, Val Loss = 6.688194, Teacher Forcing Ratio = 0.100
# Epoch 260/300: Train Loss = 8.232773, Val Loss = 6.096959, Teacher Forcing Ratio = 0.100
# Epoch 261/300: Train Loss = 8.004300, Val Loss = 6.086069, Teacher Forcing Ratio = 0.100
# Epoch 262/300: Train Loss = 8.040932, Val Loss = 5.825498, Teacher Forcing Ratio = 0.100
# Epoch 263/300: Train Loss = 8.158679, Val Loss = 6.412639, Teacher Forcing Ratio = 0.100
# Epoch 264/300: Train Loss = 8.450988, Val Loss = 6.106441, Teacher Forcing Ratio = 0.100
# Epoch 265/300: Train Loss = 8.214639, Val Loss = 5.986292, Teacher Forcing Ratio = 0.100
# Epoch 266/300: Train Loss = 8.198678, Val Loss = 5.970215, Teacher Forcing Ratio = 0.100
# Epoch 267/300: Train Loss = 8.259285, Val Loss = 5.983240, Teacher Forcing Ratio = 0.100
# Epoch 268/300: Train Loss = 8.122711, Val Loss = 6.106267, Teacher Forcing Ratio = 0.100
# Epoch 269/300: Train Loss = 8.115010, Val Loss = 5.895235, Teacher Forcing Ratio = 0.100
# Epoch 270/300: Train Loss = 8.074534, Val Loss = 5.895596, Teacher Forcing Ratio = 0.100
# Epoch 271/300: Train Loss = 8.086804, Val Loss = 5.908387, Teacher Forcing Ratio = 0.100
# Epoch 272/300: Train Loss = 8.270817, Val Loss = 5.822936, Teacher Forcing Ratio = 0.100
# Epoch 273/300: Train Loss = 8.174941, Val Loss = 5.932133, Teacher Forcing Ratio = 0.100
# Epoch 274/300: Train Loss = 7.930594, Val Loss = 5.906962, Teacher Forcing Ratio = 0.100
# Epoch 275/300: Train Loss = 8.147464, Val Loss = 5.945208, Teacher Forcing Ratio = 0.100
# Epoch 276/300: Train Loss = 8.238327, Val Loss = 6.106103, Teacher Forcing Ratio = 0.100
# Epoch 277/300: Train Loss = 8.036921, Val Loss = 5.921805, Teacher Forcing Ratio = 0.100
# Epoch 278/300: Train Loss = 8.143560, Val Loss = 5.927326, Teacher Forcing Ratio = 0.100
# Epoch 279/300: Train Loss = 7.812447, Val Loss = 5.854835, Teacher Forcing Ratio = 0.100
# Epoch 280/300: Train Loss = 7.969874, Val Loss = 5.806150, Teacher Forcing Ratio = 0.100
# Epoch 281/300: Train Loss = 8.125495, Val Loss = 5.942015, Teacher Forcing Ratio = 0.100
# Epoch 282/300: Train Loss = 7.999629, Val Loss = 6.304798, Teacher Forcing Ratio = 0.100
# Epoch 283/300: Train Loss = 8.131208, Val Loss = 6.007215, Teacher Forcing Ratio = 0.100
# Epoch 284/300: Train Loss = 8.066933, Val Loss = 6.106355, Teacher Forcing Ratio = 0.100
# Epoch 285/300: Train Loss = 7.961745, Val Loss = 5.765178, Teacher Forcing Ratio = 0.100
# Epoch 286/300: Train Loss = 8.059663, Val Loss = 5.899106, Teacher Forcing Ratio = 0.100
# Epoch 287/300: Train Loss = 8.038404, Val Loss = 6.054372, Teacher Forcing Ratio = 0.100
# Epoch 288/300: Train Loss = 8.210536, Val Loss = 5.824334, Teacher Forcing Ratio = 0.100
# Epoch 289/300: Train Loss = 7.967397, Val Loss = 5.888303, Teacher Forcing Ratio = 0.100
# Epoch 290/300: Train Loss = 7.776841, Val Loss = 5.921249, Teacher Forcing Ratio = 0.100
# Epoch 291/300: Train Loss = 7.994167, Val Loss = 5.789026, Teacher Forcing Ratio = 0.100
# Epoch 292/300: Train Loss = 7.855184, Val Loss = 5.974725, Teacher Forcing Ratio = 0.100
# Epoch 293/300: Train Loss = 7.958159, Val Loss = 6.094067, Teacher Forcing Ratio = 0.100
# Epoch 294/300: Train Loss = 7.972584, Val Loss = 5.906016, Teacher Forcing Ratio = 0.100
# Epoch 295/300: Train Loss = 8.173290, Val Loss = 5.986382, Teacher Forcing Ratio = 0.100
# Epoch 296/300: Train Loss = 8.064028, Val Loss = 5.893108, Teacher Forcing Ratio = 0.100
# Epoch 297/300: Train Loss = 7.819952, Val Loss = 5.980001, Teacher Forcing Ratio = 0.100
# Epoch 298/300: Train Loss = 7.788816, Val Loss = 6.012162, Teacher Forcing Ratio = 0.100
# Epoch 299/300: Train Loss = 8.055267, Val Loss = 5.771210, Teacher Forcing Ratio = 0.100
# Epoch 300/300: Train Loss = 7.835369, Val Loss = 6.082972, Teacher Forcing Ratio = 0.100
# Transformer 모델 Adaptive Scheduled Sampling 학습 완료.

# %%
print("\n### 학습된 모델로 테스트셋 예측 및 평가 (Autoregressive Inference) ###")
# 트랜스포머 추론은 한 스텝씩 자동 회귀 방식으로 수행

transformer_model.eval() # 평가 모드
prediction_sequences = [] # 예측된 시퀀스들을 저장할 리스트
ground_truth_sequences = [] # 실제 시퀀스들을 저장할 리스트
test_losses = [] # 각 시퀀스별 MSE 저장

with torch.no_grad(): # 그래디언트 계산 비활성화
    for batch_x, batch_y in Test_Loader:
        # batch_x shape: (batch_size, window_in, input_dim)
        # batch_y shape: (batch_size, window_out)

        batch_size_actual = batch_x.size(0) # 배치의 실제 크기 (마지막 배치는 더 작을 수 있음)

        # 인코더 입력 준비 (테스트 배치 전체에 대해 수행)
        # src shape: (window_in, batch_size_actual, d_model)
        src = transformer_model.encoder_input_layer(batch_x.permute(1, 0, 2))
        src = transformer_model.pos_encoder(src)
        # 인코더 순전파
        # memory shape: (window_in, batch_size_actual, d_model)
        memory = transformer_model.transformer_encoder(src, None) # Encoder output (memory)


        # >>> 자동 회귀 디코딩 루프 <<<
        # 각 샘플별로 예측 시퀀스를 생성
        # Decoder input은 예측 스텝에 따라 달라지므로 루프 내에서 처리
        
        # 초기 디코더 입력: 시작 토큰 (각 샘플별로 필요)
        # initial_decoder_input shape: (batch_size_actual, 1, output_dim=1)
        # 시작 토큰 값은 학습 시 사용한 것과 동일
        initial_decoder_input = torch.full((batch_size_actual, 1, output_dim), 0.0, device=device)

        # 현재까지 예측된 시퀀스 (처음에는 시작 토큰만 있음)
        # current_predicted_sequence shape: (batch_size_actual, current_seq_len, output_dim=1)
        current_predicted_sequence = initial_decoder_input

        # window_out 스텝만큼 반복하여 예측
        for _ in range(window_out): # Predict window_out steps
             # 디코더 입력 준비: 현재까지 예측된 시퀀스를 사용
             # tgt shape: (current_seq_len, batch_size_actual, output_dim=1) -> map to d_model
             tgt = transformer_model.decoder_input_layer(current_predicted_sequence.permute(1, 0, 2))
             tgt = transformer_model.pos_decoder(tgt)

             # 인과적 마스크 생성: 현재 디코더 입력 시퀀스 길이에 맞게 생성
             # mask_sz = current_predicted_sequence.size(1)
             tgt_mask_inf = generate_square_subsequent_mask(current_predicted_sequence.size(1))

             # 트랜스포머 디코더 순전파
             # output shape: (current_seq_len, batch_size_actual, d_model)
             # 디코더는 tgt와 memory를 받음
             output = transformer_model.transformer_decoder(tgt, memory, tgt_mask_inf, None)

             # 다음 스텝 예측: 디코더 출력의 가장 마지막 시점 ([ -1 , : , : ]) 결과를 사용
             # last_output_step shape: (batch_size_actual, d_model)
             last_output_step = output[-1, :, :]

             # 최종 출력 레이어를 통해 다음 값 예측
             # next_prediction shape: (batch_size_actual, output_dim=1)
             next_prediction = transformer_model.output_layer(last_output_step)

             # 예측된 다음 스텝을 현재까지의 예측 시퀀스에 추가
             # next_prediction shape (batch_size_actual, 1, output_dim=1) 로 차원 변경 후 연결
             current_predicted_sequence = torch.cat([current_predicted_sequence, next_prediction.unsqueeze(1)], dim=1)

        # 최종 예측 시퀀스: 시작 토큰 제외 (첫 스텝 제외)
        # final_predicted_sequence shape: (batch_size_actual, window_out, output_dim=1)
        final_predicted_sequence = current_predicted_sequence[:, 1:, :] # 시작 토큰 (인덱스 0) 제외


        # 실제 타겟 시퀀스 준비 (평가를 위해)
        # batch_y shape: (batch_size_actual, window_out) -> (batch_size_actual, window_out, 1)
        actual_target_sequence = batch_y.unsqueeze(-1)


        # 예측된 시퀀스와 실제 시퀀스 저장
        prediction_sequences.append(final_predicted_sequence.cpu().numpy())
        ground_truth_sequences.append(actual_target_sequence.cpu().numpy())

        # 각 시퀀스별 MSE 계산
        # output shape: (batch_size_actual, window_out, 1), target shape: (batch_size_actual, window_out, 1)
        # MSE 계산은 MSELoss를 사용하거나 수동으로 (pred - target)**2 의 평균을 구함
        batch_mse = torch.mean((final_predicted_sequence - actual_target_sequence)**2, dim=[1, 2]) # 시퀀스 길이와 특징 차원에 대해 평균
        test_losses.append(batch_mse.cpu().numpy())


# 배치별 결과를 하나로 합침
prediction_sequences = np.concatenate(prediction_sequences) # shape: (num_test_sequences, window_out, 1)
ground_truth_sequences = np.concatenate(ground_truth_sequences) # shape: (num_test_sequences, window_out, 1)
test_losses = np.concatenate(test_losses) # shape: (num_test_sequences,) - 각 시퀀스별 평균 MSE


# 테스트셋 전체 평균 MSE 계산
overall_test_mse = np.mean(test_losses)

print(f"Transformer 테스트셋 평균 MSE: {overall_test_mse:.4f}")
# Out:
# ### 학습된 모델로 테스트셋 예측 및 평가 (Autoregressive Inference) ###
# Transformer 테스트셋 평균 MSE: 7.8378

# %%
print("\n### 예측 결과 시각화 ###")
# 전체 시퀀스를 평탄화하여 시각화
plt.figure(figsize=(15,5))

# (400, 3, 1) 형태라면 squeeze 필요
plt.plot(ground_truth_sequences.squeeze(-1).reshape(-1), label="True temp_mean (°C)")
plt.plot(prediction_sequences.squeeze(-1).reshape(-1), label="Predicted temp_mean (°C)")
plt.title("Temperature Prediction (°C) - Scheduled Sampling")
plt.xlabel("Time step (flattened sequence)")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.grid(True)
plt.show()

print("\n### 특정 시퀀스 예측 상세 시각화 (Scaling 없이) ###")
num_sequences_to_plot = min(10, len(X_test))
plt.figure(figsize=(15, num_sequences_to_plot * 3))

for i in range(num_sequences_to_plot):
    plt.subplot(num_sequences_to_plot, 1, i + 1)
    time_steps = np.arange(window_out)

    # ❗ 여기서 true_seq, pred_seq 정의
    true_seq = ground_truth_sequences[i].squeeze(-1)  # (window_out,)
    pred_seq = prediction_sequences[i].squeeze(-1)    # (window_out,)

    plt.plot(time_steps, true_seq, label="True (°C)")
    plt.plot(time_steps, pred_seq, label="Predicted (°C)")
    plt.title(f"Sequence {i+1} Prediction (MSE: {test_losses[i]:.4f})")
    plt.xlabel("Days ahead")
    plt.ylabel("Temperature (°C)")
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ### 예측 결과 시각화 ###
# ### 특정 시퀀스 예측 상세 시각화 (Scaling 없이) ###
